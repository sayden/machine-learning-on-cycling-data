# %% [markdown]
# # FTP

# %%
_FTP_ = 225
_PATH_ = '/home/caster/training_data'

# %% [markdown]
# # Load dependencies

# %%
# %run -i training_functions.py

# %%
rides = read_rides(_PATH_, _FTP_)
rides[:10]
# Out:
#                         filename epoch_day time        cad          hr hr_min  \
# 0  2017_02_18_11_13_04.utf8.json     17215  118  62.952481  151.204584    104
# 0  2017_02_22_17_33_49.utf8.json     17219   67        NaN  131.801924     90
# 0  2017_03_07_17_47_18.utf8.json     17232   80  74.814179  158.177553    114
# 0  2017_03_10_17_46_57.utf8.json     17235   51  69.113340  156.281963    115
# 0  2017_03_11_17_34_54.utf8.json     17236   87  68.018194  135.779672    102
# 0  2017_03_17_18_00_29.utf8.json     17242   66  71.275000  151.941206    109
# 0  2017_03_25_18_59_41.utf8.json     17250   68  66.070627  149.505367     96
# 0  2017_03_25_18_28_52.utf8.json     17250   30  70.264559  127.160288     90
# 0  2017_04_02_18_20_32.utf8.json     17258  104  68.309573  148.765053    113
# 0  2017_04_09_17_33_55.utf8.json     17265  146  64.097612  153.115009    104
#
#   hr_max  hr_drift       km        kph      ...              tss        if  \
# ...

# %% [markdown]
# # Start here
